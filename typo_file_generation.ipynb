# %%
from datasets import get_dataset_config_names, get_dataset_split_names, load_dataset
import os

# 🔧 설정
dataset_name = "HAERAE-HUB/KMMLU"
save_dir = "KMMLU_origin"
os.makedirs(save_dir, exist_ok=True)

# 1. 모든 subset(config) 이름 가져오기
subsets = get_dataset_config_names(dataset_name)

for subset in subsets:
    try:
        # 2. subset별 split 목록 가져오기 (예: train, validation, test)
        splits = get_dataset_split_names(dataset_name, subset)
        
        for split in splits:
            print(f"📥 다운로드 중: subset={subset}, split={split}")
            
            # 3. 데이터셋 로드
            dataset = load_dataset(dataset_name, subset, split=split)
            
            # 4. 파일 이름 지정 및 저장
            json_name = f"{subset}-{split}.json"
            json_path = os.path.join(save_dir, json_name)
            
            # 5. pandas로 변환 후 저장
            df = dataset.to_pandas()
            df.to_json(json_path, orient="records", lines=True, force_ascii=False)
            
            print(f"✅ 저장 완료: {json_path}")
    
    except Exception as e:
        print(f"❌ 오류 발생: subset={subset}, split={split} → {e}")
# Out:
# 📥 다운로드 중: subset=Accounting, split=train
# ✅ 저장 완료: KMMLU_origin\Accounting-train.json
# 📥 다운로드 중: subset=Accounting, split=dev
# ✅ 저장 완료: KMMLU_origin\Accounting-dev.json
# 📥 다운로드 중: subset=Accounting, split=test
# ✅ 저장 완료: KMMLU_origin\Accounting-test.json
# 📥 다운로드 중: subset=Agricultural-Sciences, split=train
# ✅ 저장 완료: KMMLU_origin\Agricultural-Sciences-train.json
# 📥 다운로드 중: subset=Agricultural-Sciences, split=dev
# ✅ 저장 완료: KMMLU_origin\Agricultural-Sciences-dev.json
# 📥 다운로드 중: subset=Agricultural-Sciences, split=test
# ✅ 저장 완료: KMMLU_origin\Agricultural-Sciences-test.json
# 📥 다운로드 중: subset=Aviation-Engineering-and-Maintenance, split=train
# ✅ 저장 완료: KMMLU_origin\Aviation-Engineering-and-Maintenance-train.json
# 📥 다운로드 중: subset=Aviation-Engineering-and-Maintenance, split=dev
# ✅ 저장 완료: KMMLU_origin\Aviation-Engineering-and-Maintenance-dev.json
# 📥 다운로드 중: subset=Aviation-Engineering-and-Maintenance, split=test
# ✅ 저장 완료: KMMLU_origin\Aviation-Engineering-and-Maintenance-test.json
# 📥 다운로드 중: subset=Biology, split=train
# ✅ 저장 완료: KMMLU_origin\Biology-train.json
# 📥 다운로드 중: subset=Biology, split=dev
# ✅ 저장 완료: KMMLU_origin\Biology-dev.json
# 📥 다운로드 중: subset=Biology, split=test
# ✅ 저장 완료: KMMLU_origin\Biology-test.json
# 📥 다운로드 중: subset=Chemical-Engineering, split=train
# ✅ 저장 완료: KMMLU_origin\Chemical-Engineering-train.json
# 📥 다운로드 중: subset=Chemical-Engineering, split=dev
# ✅ 저장 완료: KMMLU_origin\Chemical-Engineering-dev.json
# 📥 다운로드 중: subset=Chemical-Engineering, split=test
# ✅ 저장 완료: KMMLU_origin\Chemical-Engineering-test.json
# 📥 다운로드 중: subset=Chemistry, split=train
# ✅ 저장 완료: KMMLU_origin\Chemistry-train.json
# 📥 다운로드 중: subset=Chemistry, split=dev
# ✅ 저장 완료: KMMLU_origin\Chemistry-dev.json
# 📥 다운로드 중: subset=Chemistry, split=test
# ✅ 저장 완료: KMMLU_origin\Chemistry-test.json
# 📥 다운로드 중: subset=Civil-Engineering, split=train
# ✅ 저장 완료: KMMLU_origin\Civil-Engineering-train.json
# 📥 다운로드 중: subset=Civil-Engineering, split=dev
# ✅ 저장 완료: KMMLU_origin\Civil-Engineering-dev.json
# 📥 다운로드 중: subset=Civil-Engineering, split=test
# ✅ 저장 완료: KMMLU_origin\Civil-Engineering-test.json
# 📥 다운로드 중: subset=Computer-Science, split=train
# ✅ 저장 완료: KMMLU_origin\Computer-Science-train.json
# 📥 다운로드 중: subset=Computer-Science, split=dev
# ✅ 저장 완료: KMMLU_origin\Computer-Science-dev.json
# 📥 다운로드 중: subset=Computer-Science, split=test
# ✅ 저장 완료: KMMLU_origin\Computer-Science-test.json
# 📥 다운로드 중: subset=Construction, split=train
# ✅ 저장 완료: KMMLU_origin\Construction-train.json
# 📥 다운로드 중: subset=Construction, split=dev
# ✅ 저장 완료: KMMLU_origin\Construction-dev.json
# 📥 다운로드 중: subset=Construction, split=test
# ✅ 저장 완료: KMMLU_origin\Construction-test.json
# 📥 다운로드 중: subset=Criminal-Law, split=train
# ✅ 저장 완료: KMMLU_origin\Criminal-Law-train.json
# 📥 다운로드 중: subset=Criminal-Law, split=dev
# ✅ 저장 완료: KMMLU_origin\Criminal-Law-dev.json
# 📥 다운로드 중: subset=Criminal-Law, split=test
# ✅ 저장 완료: KMMLU_origin\Criminal-Law-test.json
# 📥 다운로드 중: subset=Ecology, split=train
# ✅ 저장 완료: KMMLU_origin\Ecology-train.json
# 📥 다운로드 중: subset=Ecology, split=dev
# ✅ 저장 완료: KMMLU_origin\Ecology-dev.json
# 📥 다운로드 중: subset=Ecology, split=test
# ✅ 저장 완료: KMMLU_origin\Ecology-test.json
# 📥 다운로드 중: subset=Economics, split=train
# ✅ 저장 완료: KMMLU_origin\Economics-train.json
# 📥 다운로드 중: subset=Economics, split=dev
# ✅ 저장 완료: KMMLU_origin\Economics-dev.json
# 📥 다운로드 중: subset=Economics, split=test
# ✅ 저장 완료: KMMLU_origin\Economics-test.json
# 📥 다운로드 중: subset=Education, split=train
# ✅ 저장 완료: KMMLU_origin\Education-train.json
# 📥 다운로드 중: subset=Education, split=dev
# ✅ 저장 완료: KMMLU_origin\Education-dev.json
# 📥 다운로드 중: subset=Education, split=test
# ✅ 저장 완료: KMMLU_origin\Education-test.json
# 📥 다운로드 중: subset=Electrical-Engineering, split=train
# ✅ 저장 완료: KMMLU_origin\Electrical-Engineering-train.json
# 📥 다운로드 중: subset=Electrical-Engineering, split=dev
# ✅ 저장 완료: KMMLU_origin\Electrical-Engineering-dev.json
# 📥 다운로드 중: subset=Electrical-Engineering, split=test
# ✅ 저장 완료: KMMLU_origin\Electrical-Engineering-test.json
# 📥 다운로드 중: subset=Electronics-Engineering, split=train
# ✅ 저장 완료: KMMLU_origin\Electronics-Engineering-train.json
# 📥 다운로드 중: subset=Electronics-Engineering, split=dev
# ✅ 저장 완료: KMMLU_origin\Electronics-Engineering-dev.json
# 📥 다운로드 중: subset=Electronics-Engineering, split=test
# ✅ 저장 완료: KMMLU_origin\Electronics-Engineering-test.json
# 📥 다운로드 중: subset=Energy-Management, split=train
# ✅ 저장 완료: KMMLU_origin\Energy-Management-train.json
# 📥 다운로드 중: subset=Energy-Management, split=dev
# ✅ 저장 완료: KMMLU_origin\Energy-Management-dev.json
# 📥 다운로드 중: subset=Energy-Management, split=test
# ✅ 저장 완료: KMMLU_origin\Energy-Management-test.json
# 📥 다운로드 중: subset=Environmental-Science, split=train
# ✅ 저장 완료: KMMLU_origin\Environmental-Science-train.json
# 📥 다운로드 중: subset=Environmental-Science, split=dev
# ✅ 저장 완료: KMMLU_origin\Environmental-Science-dev.json
# 📥 다운로드 중: subset=Environmental-Science, split=test
# ✅ 저장 완료: KMMLU_origin\Environmental-Science-test.json
# 📥 다운로드 중: subset=Fashion, split=train
# ✅ 저장 완료: KMMLU_origin\Fashion-train.json
# 📥 다운로드 중: subset=Fashion, split=dev
# ✅ 저장 완료: KMMLU_origin\Fashion-dev.json
# 📥 다운로드 중: subset=Fashion, split=test
# ✅ 저장 완료: KMMLU_origin\Fashion-test.json
# 📥 다운로드 중: subset=Food-Processing, split=train
# ✅ 저장 완료: KMMLU_origin\Food-Processing-train.json
# 📥 다운로드 중: subset=Food-Processing, split=dev
# ✅ 저장 완료: KMMLU_origin\Food-Processing-dev.json
# 📥 다운로드 중: subset=Food-Processing, split=test
# ✅ 저장 완료: KMMLU_origin\Food-Processing-test.json
# 📥 다운로드 중: subset=Gas-Technology-and-Engineering, split=train
# ✅ 저장 완료: KMMLU_origin\Gas-Technology-and-Engineering-train.json
# 📥 다운로드 중: subset=Gas-Technology-and-Engineering, split=dev
# ✅ 저장 완료: KMMLU_origin\Gas-Technology-and-Engineering-dev.json
# 📥 다운로드 중: subset=Gas-Technology-and-Engineering, split=test
# ✅ 저장 완료: KMMLU_origin\Gas-Technology-and-Engineering-test.json
# 📥 다운로드 중: subset=Geomatics, split=train
# ✅ 저장 완료: KMMLU_origin\Geomatics-train.json
# 📥 다운로드 중: subset=Geomatics, split=dev
# ✅ 저장 완료: KMMLU_origin\Geomatics-dev.json
# 📥 다운로드 중: subset=Geomatics, split=test
# ✅ 저장 완료: KMMLU_origin\Geomatics-test.json
# 📥 다운로드 중: subset=Health, split=train
# ✅ 저장 완료: KMMLU_origin\Health-train.json
# 📥 다운로드 중: subset=Health, split=dev
# ✅ 저장 완료: KMMLU_origin\Health-dev.json
# 📥 다운로드 중: subset=Health, split=test
# ✅ 저장 완료: KMMLU_origin\Health-test.json
# 📥 다운로드 중: subset=Industrial-Engineer, split=train
# ✅ 저장 완료: KMMLU_origin\Industrial-Engineer-train.json
# 📥 다운로드 중: subset=Industrial-Engineer, split=dev
# ✅ 저장 완료: KMMLU_origin\Industrial-Engineer-dev.json
# 📥 다운로드 중: subset=Industrial-Engineer, split=test
# ✅ 저장 완료: KMMLU_origin\Industrial-Engineer-test.json
# 📥 다운로드 중: subset=Information-Technology, split=train
# ✅ 저장 완료: KMMLU_origin\Information-Technology-train.json
# 📥 다운로드 중: subset=Information-Technology, split=dev
# ✅ 저장 완료: KMMLU_origin\Information-Technology-dev.json
# 📥 다운로드 중: subset=Information-Technology, split=test
# ✅ 저장 완료: KMMLU_origin\Information-Technology-test.json
# 📥 다운로드 중: subset=Interior-Architecture-and-Design, split=train
# ✅ 저장 완료: KMMLU_origin\Interior-Architecture-and-Design-train.json
# 📥 다운로드 중: subset=Interior-Architecture-and-Design, split=dev
# ✅ 저장 완료: KMMLU_origin\Interior-Architecture-and-Design-dev.json
# 📥 다운로드 중: subset=Interior-Architecture-and-Design, split=test
# ✅ 저장 완료: KMMLU_origin\Interior-Architecture-and-Design-test.json
# 📥 다운로드 중: subset=Law, split=train
# ✅ 저장 완료: KMMLU_origin\Law-train.json
# 📥 다운로드 중: subset=Law, split=dev
# ✅ 저장 완료: KMMLU_origin\Law-dev.json
# 📥 다운로드 중: subset=Law, split=test
# ✅ 저장 완료: KMMLU_origin\Law-test.json
# 📥 다운로드 중: subset=Machine-Design-and-Manufacturing, split=train
# ✅ 저장 완료: KMMLU_origin\Machine-Design-and-Manufacturing-train.json
# 📥 다운로드 중: subset=Machine-Design-and-Manufacturing, split=dev
# ✅ 저장 완료: KMMLU_origin\Machine-Design-and-Manufacturing-dev.json
# 📥 다운로드 중: subset=Machine-Design-and-Manufacturing, split=test
# ✅ 저장 완료: KMMLU_origin\Machine-Design-and-Manufacturing-test.json
# 📥 다운로드 중: subset=Management, split=train
# ✅ 저장 완료: KMMLU_origin\Management-train.json
# 📥 다운로드 중: subset=Management, split=dev
# ✅ 저장 완료: KMMLU_origin\Management-dev.json
# 📥 다운로드 중: subset=Management, split=test
# ✅ 저장 완료: KMMLU_origin\Management-test.json
# 📥 다운로드 중: subset=Maritime-Engineering, split=train
# ✅ 저장 완료: KMMLU_origin\Maritime-Engineering-train.json
# 📥 다운로드 중: subset=Maritime-Engineering, split=dev
# ✅ 저장 완료: KMMLU_origin\Maritime-Engineering-dev.json
# 📥 다운로드 중: subset=Maritime-Engineering, split=test
# ✅ 저장 완료: KMMLU_origin\Maritime-Engineering-test.json
# 📥 다운로드 중: subset=Marketing, split=train
# ✅ 저장 완료: KMMLU_origin\Marketing-train.json
# 📥 다운로드 중: subset=Marketing, split=dev
# ✅ 저장 완료: KMMLU_origin\Marketing-dev.json
# 📥 다운로드 중: subset=Marketing, split=test
# ✅ 저장 완료: KMMLU_origin\Marketing-test.json
# 📥 다운로드 중: subset=Materials-Engineering, split=train
# ✅ 저장 완료: KMMLU_origin\Materials-Engineering-train.json
# 📥 다운로드 중: subset=Materials-Engineering, split=dev
# ✅ 저장 완료: KMMLU_origin\Materials-Engineering-dev.json
# 📥 다운로드 중: subset=Materials-Engineering, split=test
# ✅ 저장 완료: KMMLU_origin\Materials-Engineering-test.json
# 📥 다운로드 중: subset=Mechanical-Engineering, split=train
# ✅ 저장 완료: KMMLU_origin\Mechanical-Engineering-train.json
# 📥 다운로드 중: subset=Mechanical-Engineering, split=dev
# ✅ 저장 완료: KMMLU_origin\Mechanical-Engineering-dev.json
# 📥 다운로드 중: subset=Mechanical-Engineering, split=test
# ✅ 저장 완료: KMMLU_origin\Mechanical-Engineering-test.json
# 📥 다운로드 중: subset=Nondestructive-Testing, split=train
# ✅ 저장 완료: KMMLU_origin\Nondestructive-Testing-train.json
# 📥 다운로드 중: subset=Nondestructive-Testing, split=dev
# ✅ 저장 완료: KMMLU_origin\Nondestructive-Testing-dev.json
# 📥 다운로드 중: subset=Nondestructive-Testing, split=test
# ✅ 저장 완료: KMMLU_origin\Nondestructive-Testing-test.json
# 📥 다운로드 중: subset=Patent, split=train
# ✅ 저장 완료: KMMLU_origin\Patent-train.json
# 📥 다운로드 중: subset=Patent, split=dev
# ✅ 저장 완료: KMMLU_origin\Patent-dev.json
# 📥 다운로드 중: subset=Patent, split=test
# ✅ 저장 완료: KMMLU_origin\Patent-test.json
# 📥 다운로드 중: subset=Political-Science-and-Sociology, split=train
# ✅ 저장 완료: KMMLU_origin\Political-Science-and-Sociology-train.json
# 📥 다운로드 중: subset=Political-Science-and-Sociology, split=dev
# ✅ 저장 완료: KMMLU_origin\Political-Science-and-Sociology-dev.json
# 📥 다운로드 중: subset=Political-Science-and-Sociology, split=test
# ✅ 저장 완료: KMMLU_origin\Political-Science-and-Sociology-test.json
# 📥 다운로드 중: subset=Psychology, split=train
# ✅ 저장 완료: KMMLU_origin\Psychology-train.json
# 📥 다운로드 중: subset=Psychology, split=dev
# ✅ 저장 완료: KMMLU_origin\Psychology-dev.json
# 📥 다운로드 중: subset=Psychology, split=test
# ✅ 저장 완료: KMMLU_origin\Psychology-test.json
# 📥 다운로드 중: subset=Public-Safety, split=train
# ✅ 저장 완료: KMMLU_origin\Public-Safety-train.json
# 📥 다운로드 중: subset=Public-Safety, split=dev
# ✅ 저장 완료: KMMLU_origin\Public-Safety-dev.json
# 📥 다운로드 중: subset=Public-Safety, split=test
# ✅ 저장 완료: KMMLU_origin\Public-Safety-test.json
# 📥 다운로드 중: subset=Railway-and-Automotive-Engineering, split=train
# ✅ 저장 완료: KMMLU_origin\Railway-and-Automotive-Engineering-train.json
# 📥 다운로드 중: subset=Railway-and-Automotive-Engineering, split=dev
# ✅ 저장 완료: KMMLU_origin\Railway-and-Automotive-Engineering-dev.json
# 📥 다운로드 중: subset=Railway-and-Automotive-Engineering, split=test
# ✅ 저장 완료: KMMLU_origin\Railway-and-Automotive-Engineering-test.json
# 📥 다운로드 중: subset=Real-Estate, split=train
# ✅ 저장 완료: KMMLU_origin\Real-Estate-train.json
# 📥 다운로드 중: subset=Real-Estate, split=dev
# ✅ 저장 완료: KMMLU_origin\Real-Estate-dev.json
# 📥 다운로드 중: subset=Real-Estate, split=test
# ✅ 저장 완료: KMMLU_origin\Real-Estate-test.json
# 📥 다운로드 중: subset=Refrigerating-Machinery, split=train
# ✅ 저장 완료: KMMLU_origin\Refrigerating-Machinery-train.json
# 📥 다운로드 중: subset=Refrigerating-Machinery, split=dev
# ✅ 저장 완료: KMMLU_origin\Refrigerating-Machinery-dev.json
# 📥 다운로드 중: subset=Refrigerating-Machinery, split=test
# ✅ 저장 완료: KMMLU_origin\Refrigerating-Machinery-test.json
# 📥 다운로드 중: subset=Social-Welfare, split=train
# ✅ 저장 완료: KMMLU_origin\Social-Welfare-train.json
# 📥 다운로드 중: subset=Social-Welfare, split=dev
# ✅ 저장 완료: KMMLU_origin\Social-Welfare-dev.json
# 📥 다운로드 중: subset=Social-Welfare, split=test
# ✅ 저장 완료: KMMLU_origin\Social-Welfare-test.json
# 📥 다운로드 중: subset=Taxation, split=train
# ✅ 저장 완료: KMMLU_origin\Taxation-train.json
# 📥 다운로드 중: subset=Taxation, split=dev
# ✅ 저장 완료: KMMLU_origin\Taxation-dev.json
# 📥 다운로드 중: subset=Taxation, split=test
# ✅ 저장 완료: KMMLU_origin\Taxation-test.json
# 📥 다운로드 중: subset=Telecommunications-and-Wireless-Technology, split=train
# ✅ 저장 완료: KMMLU_origin\Telecommunications-and-Wireless-Technology-train.json
# 📥 다운로드 중: subset=Telecommunications-and-Wireless-Technology, split=dev
# ✅ 저장 완료: KMMLU_origin\Telecommunications-and-Wireless-Technology-dev.json
# 📥 다운로드 중: subset=Telecommunications-and-Wireless-Technology, split=test
# ✅ 저장 완료: KMMLU_origin\Telecommunications-and-Wireless-Technology-test.json
# 📥 다운로드 중: subset=Korean-History, split=train
# ✅ 저장 완료: KMMLU_origin\Korean-History-train.json
# 📥 다운로드 중: subset=Korean-History, split=dev
# ✅ 저장 완료: KMMLU_origin\Korean-History-dev.json
# 📥 다운로드 중: subset=Korean-History, split=test
# ✅ 저장 완료: KMMLU_origin\Korean-History-test.json
# 📥 다운로드 중: subset=Math, split=train
# ✅ 저장 완료: KMMLU_origin\Math-train.json
# 📥 다운로드 중: subset=Math, split=dev
# ✅ 저장 완료: KMMLU_origin\Math-dev.json
# 📥 다운로드 중: subset=Math, split=test
# ✅ 저장 완료: KMMLU_origin\Math-test.json

# %%
import pandas as pd
import os

# 🔧 설정
json_dir = "KMMLU_origin"
save_dir = "./KMMLU_Typo_Generated"
column = "question"
typo_types = ["introduce_typo", "drop_jongsung", "repeat_char", "merge_words", "swap_parts"]
count_range = range(1, 6)
ratio = None
max_repeat = 3

# Typo 타입 → 인덱스 매핑
typo_idx_map = {
    "introduce_typo": 1,
    "drop_jongsung": 2,
    "repeat_char": 3,
    "merge_words": 4,
    "swap_parts": 5
}

from typo_generation_modules import (
    introduce_typo_to_sentence,
    drop_jongsung_sentence,
    repeat_char_typo_no_space,
    merge_words_typo,
    swap_parts_in_sentence,
)

# test JSON 파일만 대상
json_paths = [
    os.path.join(json_dir, f)
    for f in os.listdir(json_dir)
    if f.endswith("-test.json")
]

# 저장 폴더 만들기
os.makedirs(save_dir, exist_ok=True)

# 처리 시작
for json_path in json_paths:
    df = pd.read_json(json_path, lines=True)
    base_filename = os.path.basename(json_path).replace(".json", "")

    if column in df.columns:
        for typo_type in typo_types:
            prev_indices = [set() for _ in range(len(df))]  # introduce_typo 전용

            for level in count_range:
                if level == 1:
                    df_work = df.copy()
                    texts = df_work[column].astype(str).tolist()
                else:
                    prev_name = f"{base_filename}_typo_{typo_idx_map[typo_type]}_level_{level-1}.json"
                    prev_path = os.path.join(save_dir, prev_name)
                    df_work = pd.read_json(prev_path, lines=True)
                    texts = df_work[column].astype(str).tolist()

                new_texts = []

                if typo_type == "introduce_typo":
                    for i, text in enumerate(texts):
                        new_text, applied = introduce_typo_to_sentence(
                            text,
                            count=1,
                            ratio=ratio,
                            skip_indices=prev_indices[i]
                        )
                        new_texts.append(new_text)
                        prev_indices[i].update(applied)
                    df_work[column] = new_texts

                else:
                    typo_funcs = {
                        "drop_jongsung": lambda text: drop_jongsung_sentence(text, count=1, ratio=ratio),
                        "repeat_char": lambda text: repeat_char_typo_no_space(text, count=1, ratio=ratio, max_repeat=max_repeat),
                        "merge_words": lambda text: merge_words_typo(text, count=1, ratio=ratio),
                        "swap_parts": lambda text: swap_parts_in_sentence(text, count=1, ratio=ratio)
                    }
                    df_work[column] = [typo_funcs[typo_type](text) for text in texts]

                save_name = f"{base_filename}_typo_{typo_idx_map[typo_type]}_level_{level}.json"
                save_path = os.path.join(save_dir, save_name)
                df_work.to_json(save_path, orient="records", lines=True, force_ascii=False)
                print(f"✅ 저장 완료: {save_path}")
# Out:
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Accounting-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Agricultural-Sciences-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Aviation-Engineering-and-Maintenance-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Biology-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemical-Engineering-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Chemistry-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Civil-Engineering-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Computer-Science-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Construction-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Criminal-Law-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Ecology-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Economics-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Education-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electrical-Engineering-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Electronics-Engineering-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Energy-Management-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Environmental-Science-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Fashion-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Food-Processing-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Gas-Technology-and-Engineering-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Geomatics-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Health-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Industrial-Engineer-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Information-Technology-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Interior-Architecture-and-Design-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Korean-History-test_typo_5_level_1.json
# ...
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Political-Science-and-Sociology-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Political-Science-and-Sociology-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Political-Science-and-Sociology-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Political-Science-and-Sociology-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Political-Science-and-Sociology-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Psychology-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Public-Safety-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Railway-and-Automotive-Engineering-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Real-Estate-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Refrigerating-Machinery-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Social-Welfare-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Taxation-test_typo_5_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_1_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_1_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_1_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_1_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_1_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_2_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_2_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_2_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_2_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_2_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_3_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_3_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_3_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_3_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_3_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_4_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_4_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_4_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_4_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_4_level_5.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_5_level_1.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_5_level_2.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_5_level_3.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_5_level_4.json
# ✅ 저장 완료: ./KMMLU_Typo_Generated\Telecommunications-and-Wireless-Technology-test_typo_5_level_5.json

# %%
import os
import json
from collections import defaultdict

# 🔧 설정
base_dir = "KMMLU_Typo_Generated"  # typo가 적용된 파일들이 있는 곳
final_dir = "All_KMMLU_Typo_Tests"  # 최종 병합 결과 저장 폴더

# 📁 폴더 생성
os.makedirs(final_dir, exist_ok=True)

# 🔍 typo_type + level 추출 함수
def extract_typo_info(filename):
    parts = filename.split("_")
    typo = parts[-3]  # e.g., 'typo_1'
    level = parts[-1].replace(".json", "")  # e.g., '5'
    return typo, level

# 🧩 파일 그룹화
grouped_files = defaultdict(lambda: defaultdict(list))
files = [f for f in os.listdir(base_dir) if f.endswith(".json") and "test" in f]
for filename in files:
    typo, level = extract_typo_info(filename)
    grouped_files[typo][level].append(filename)

# 📦 병합 후 저장 (중간 폴더 없이 바로)
for typo_type in grouped_files:
    for level in grouped_files[typo_type]:
        combined_data = {}
        for file in grouped_files[typo_type][level]:
            full_path = os.path.join(base_dir, file)
            with open(full_path, "r", encoding="utf-8") as f:
                lines = f.readlines()
                parsed_lines = [json.loads(line) for line in lines if line.strip()]
            dataset_name = file.split("-")[0]  # e.g., Accounting
            combined_data[dataset_name] = parsed_lines

        # 📄 파일 이름: KMMLU_typo_{n}_level_{m}.json
        save_filename = f"KMMLU_{typo_type}_level_{level}.json"
        save_path = os.path.join(final_dir, save_filename)

        with open(save_path, "w", encoding="utf-8") as f:
            json.dump(combined_data, f, ensure_ascii=False, indent=2)

print("✅ All typo-level test files have been merged and saved.")
# Out:
# ✅ All typo-level test files have been merged and saved.

# %%
import os
import subprocess
import shutil

# [1] 설정
repo_url = "https://github.com/CAU-AI-Project-Team5/K-Typo.git"
local_repo_path = "."
source_dir = "All_KMMLU_Typo_Tests"
target_dir = os.path.join("Datasets", "KMMLU")

# [2] Git 초기화
if not os.path.exists(os.path.join(local_repo_path, ".git")):
    subprocess.run(["git", "init"], cwd=local_repo_path)

# [3] 원격 저장소 연결
remotes = subprocess.run(["git", "remote"], cwd=local_repo_path, capture_output=True, text=True).stdout
if "origin" not in remotes:
    subprocess.run(["git", "remote", "add", "origin", repo_url], cwd=local_repo_path)

# [4] main 브랜치가 없으면 생성
branches = subprocess.run(["git", "branch"], cwd=local_repo_path, capture_output=True, text=True).stdout
if "main" not in branches:
    subprocess.run(["git", "checkout", "-b", "main"], cwd=local_repo_path)

# [5] Datasets/KMMLU 폴더 생성
os.makedirs(target_dir, exist_ok=True)

# [6] typo 파일 복사
for file in os.listdir(source_dir):
    if file.endswith(".json"):
        shutil.copy(os.path.join(source_dir, file), os.path.join(target_dir, file))

# [7] Git add + commit
subprocess.run(["git", "add", "."], cwd=local_repo_path)
subprocess.run(["git", "commit", "-m", "Move KMMLU_typo files into Datasets/KMMLU"], cwd=local_repo_path)

# [8] Git pull --rebase
subprocess.run(["git", "pull", "--rebase", "origin", "main"], cwd=local_repo_path)

# [9] Git push
result = subprocess.run(["git", "push", "-u", "origin", "main"], cwd=local_repo_path, capture_output=True, text=True)


# 결과 출력
print("stdout:\n", result.stdout)
print("stderr:\n", result.stderr)
print("returncode:", result.returncode)
# Out:
# stdout:
#
# stderr:
#  To https://github.com/CAU-AI-Project-Team5/K-Typo.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/CAU-AI-Project-Team5/K-Typo.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. If you want to integrate the remote changes,
# hint: use 'git pull' before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
#
# returncode: 1
